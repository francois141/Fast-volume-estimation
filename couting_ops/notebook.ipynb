# %%
import math

flops =[125335,678404,2647287,8612096,22571953,49834308,96957220,178809942,296391069,477210445,734802798,1090473219,1557554608,2167945114,2944102464,3972460912,5192492196,6744427644,8561321068,10812176896,13510028426,16678328096,20387076774,24720519009,29667692509,35405176408,41833437484,49253716976,57609240203,67335590406
]

def get_flops(N):
    if N == 10:
        return 461_242_951
    M = 2 * N
    M = 1600 * 2 * N

    return 6 * N ** 3 * math.log(N, 2) ** 2 * M
            # 3 * N ** 2 * math.log(N, 2) ** 2 + \
            # 3 * N ** 2 * math.log(N, 2) ** 2 * M + \
            # 6 * N ** 2 * math.log(N, 2) + \
            # 4 * N * math.log(N, 2) + \
            # 4 * N ** 2 * math.log(N, 2)

# %%
cycles = [
    1331875,
3927075,
11326193,
27926574,
60676256,
115020428,
199932414,
335129165,
614495675,
922583415,
1292282003,
1779073648,
2293587862,
3087393270,
4224219136,
5352743830,
7204089786,
9119692269,
11348319627,
15581924487,
19206526531,
23300232309,
25318244031,
30276969069,
36065694695,
42520485068,
49959747733,
58457034785,
68134660121,
79012417311,

]

# %%
for i in range(1, 31):
    print(f"cube_{i}: {flops[i - 1] / cycles[i - 1]}")
# Out:
# cube_1: 0.05843144852295821
# cube_2: 0.13568995236545262
# cube_3: 0.20018828658791754
# cube_4: 0.30408654408407
# cube_5: 0.3834120076972233
# cube_6: 0.46126541900512835
# cube_7: 0.5081316293087028
# cube_8: 0.5042851138604112
# cube_9: 0.631862501356832
# cube_10: 0.7251238850043038
# cube_11: 0.8191845640488534
# cube_12: 0.8451670331528888
# cube_13: 0.8933946840519241
# cube_14: 0.9562605286694459
# cube_15: 1.0200338332285606
# cube_16: 1.0604413209361274
# cube_17: 1.0910365243919238
# cube_18: 1.1924204485475307
# cube_19: 1.16731554463902
# cube_20: 1.2636396840762516
# cube_21: 1.2546197385308822
# cube_22: 1.2953646025353798
# cube_23: 1.2938905782461603
# cube_24: 1.4067152740674937
# cube_25: 1.3890242373068291
# cube_26: 1.423033766927106
# cube_27: 1.3581409951147525
# cube_28: 1.493513373089375
# cube_29: 1.4331997112255044
# cube_30: 1.4549015337272002

# %%
flops = [12378672,193239315,1089328271,3763869650,9801704700,21838952918,42141292791,75472585851,126512402816,201360447003]
cycles = [
    38437386,
362418233,
1609899586,
5479368899,
12085567222,
26319455438,
50382371080,
87971047920,
144321798636,
232248662270
]

# %%
for i in range(1, 11):
    print(f"simplex_{i * 5}: {flops[i - 1] / cycles[i - 1]}")
# Out:
# simplex_5: 0.45182609382291755
# simplex_10: 0.8839389460223146
# simplex_15: 1.0960569087946663
# simplex_20: 1.4041593574412108
# simplex_25: 1.617142112194055
# simplex_30: 1.8131487504183748
# simplex_35: 1.776755174443761
# simplex_40: 1.7943327244800011
# simplex_45: 1.8006217292113005
# simplex_50: 1.9129223907027237
